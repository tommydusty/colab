# %%
#@title Mount Drive

import os
from google.colab import drive

if not os.path.exists('/content/drive'):
	drive.mount('/content/drive')
else:
	print('Drive is already mounted.')

# %%
#@title Save

# down_link = "https://example.com/file.rar" #@param {type:"string"}
# file_name = "file1.rar" #@param {type:"string"}

# !wget -O "morgan.zip" "https://huggingface.co/G-Force-1/arthurmorgan/resolve/main/morgan_700e_69300s.zip"
# !mkdir meme
# !unzip morgan.zip -d meme/

# %cd /content

save_path = '/content/drive/MyDrive/RVC_Backup/' #@param {type:"string"}
model = 'kaavoos' #@param {type:"string"}

# !mkdir meme
os.makedirs("meme", exist_ok=True)
# !sleep 3

# !cp "{save_path}{model}/{model}.index" "meme/added_{model}_v2.index"
# !cp $(find '{save_path}{model}/' -name '{model}_*e_*s.pth') meme/

# %cd meme/
# !sleep 5
# !zip -0 -r "{model}.zip" *
# !sleep 5
# !mv "{model}.zip" "{save_path}{model}/{model}.zip"

# --compression-method store
# -0
#
# -s 9m

# zip -r morgan.zip meme/

# %%
#@title Save 2

# %cd /content

model = "voos" #@param {type:"string"}
log_path = f"/content/Applio/logs/{model}" #@param {type:"string"}
save_path = f"/content/drive/MyDrive/RVC_Backup/{model}" #@param {type:"string"}
last_weight = 250 #@param {type:"integer"}

# !mkdir meme
os.makedirs(save_path, exist_ok=True)
# !sleep 3

# !cp "{log_path}/{model}.index" "{save_path}/added_{model}_v2.index"
# !cp $(find "{log_path}/" -name "{model}_*e_{last_weight}s.pth") "{save_path}/"
# !cp $(find "{log_path}/" -name "*_{last_weight}.pth") "{save_path}/"

# !cp "{log_path}/config.json" "{save_path}/config.json"
# !cp "{log_path}/filelist.txt" "{save_path}/filelist.txt"
# !cp "{log_path}/model_info.json" "{save_path}/model_info.json"

# %cd meme/
# !zip -0 -r "{model}.zip" *
# !mv "{model}.zip" "{save_path}{model}/{model}.zip"
